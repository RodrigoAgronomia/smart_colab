# %%
import os
import cv2
import csv
import time
import json
import numpy as np
import pandas as pd

import torch
import torch.nn.functional as F

import matplotlib.pyplot as plt
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
from cnn.Model import EESPNet_Seg

# %%
#Define o mapa de cores para geração da máscara
def colorir(cat):
    h, w = cat.shape[:2]
    msk = np.zeros((h,w,3), dtype = 'uint8')
    msk[cat == 1] = [0,0,255]
    msk[cat == 2] = [128,0,0]
    msk[cat == 3] = [255,0,0]
    msk[cat == 4] = [0,128,0]
    msk[cat == 5] = [0,255,0]
    return(msk)

# %%
def transform(x):
    x = x.copy()
    x = x.astype('float')
    x -= 128
    x /= 35
    return(x)

# %%
def calc_b(total_dim, input_dim, margin):
    n = int(np.ceil(total_dim/input_dim))
    if n == 1:
        xo = x = np.array([[0], [total_dim]])
        return(x, xo)
    
    out_dim = total_dim/n

    c = np.repeat(np.array([[-1, 1]]), n, 0)
    c[[0,-1]] = np.array([[0,1], [-1,0]])
    c = np.int0(margin * c.transpose())

    b = out_dim * (0.5 + np.arange(n))
    b0 = b - 0.5 * out_dim
    b1 = b0 + out_dim
    bb = np.stack([b0, b1])

    x = np.int0(c + bb)

    xdim = np.int0(32 * np.round((x[1] - x[0])/32))
    x[0,1:] = x[1,1:] - xdim[1:]
    x[1,0] = x[0,0] + xdim[0]
    xo = np.int0(bb - x)
    xo[1] += x[1] - x[0]
    return(x, xo)

def calc_bb(tw, th, iw, ih):
    xc, xco = calc_b(tw, iw, 128)
    yc, yco = calc_b(th, ih, 128)
    return([xc, yc, xco, yco])

# %%
n_classes = 2

model = EESPNet_Seg(n_classes, s=2, channels = 3)
model = model.to(device)
model.load_state_dict(torch.load('../data/model_drone_GP_best.pth'))

model.eval()
print('Modelo OK')
# Out:
# Modelo OK

# %%
# Diretório das imagens
im_dir = '../../Datasets/SoybeanTS/SP/' 
s_dir = '../../Datasets/SoybeanTS/pred/'

img_ext = '.JPG'

imfx = sorted(os.listdir(im_dir))
imfx = [i for i in imfx if i.endswith(img_ext) and not i.endswith('_pred.png')]
ims = np.array(imfx)
print(len(ims))
# Out:
# 70

# %%
regions = []
for idx, i in enumerate(ims):
    start_time = time.time()
    print(i)
    img_name = os.path.join(im_dir, i)
    new_img_name =  os.path.join(s_dir, i.replace('.JPG','_pred.jpg'))
    if os.path.exists(new_img_name):
        continue

    imgo = cv2.imread(img_name)
    s = 2#ls[idx]
    imgr = cv2.resize(imgo, (int(imgo.shape[1] * s), int(imgo.shape[0] * s)))
    img = transform(imgr)
    
    input_height = 1000
    input_width = 1000
    
    total_width, total_height = img.shape[:2]
    xc, yc, xco, yco = calc_bb(total_width, total_height, input_height, input_width)

    time_taken = time.time() - start_time
    print('PreProc time: %.2f' % time_taken)
    
    print(yc.shape[1], xc.shape[1])

    preds_l = []
    for yi in range(yc.shape[1]):
        preds_x = []
        for xi in range(xc.shape[1]):
            im = img[xc[0,xi]:xc[1,xi],yc[0,yi]:yc[1,yi]]
            im = np.moveaxis(im, 2, 0)
            img_tensor = torch.from_numpy(im)
            img_variable = img_tensor.unsqueeze(0).to(device, dtype=torch.float)
            with torch.no_grad():
                preds = model(img_variable)
            preds = preds[0,:,xco[0,xi]:xco[1,xi],yco[0,yi]:yco[1,yi]]


            cat = preds.argmax(0)
            pred_tensor = preds[[1]]
            predm = F.max_pool2d(pred_tensor, stride=1, kernel_size=65, padding=32)
            predm = ((predm == pred_tensor).to(device, dtype=torch.long)*cat)
            preds = torch.cat([predm.to(device, dtype=torch.float), preds], 0)

            preds_x.append(preds.cpu().data.numpy())

        preds_l.append(np.concatenate(preds_x, 1))

    pred = np.concatenate(preds_l, 2)
    
    prednorm = 255 * (pred[1] - pred[1].min())/(pred[1].max() - pred[1].min())
    prednormr = cv2.resize(prednorm, (imgo.shape[1], imgo.shape[0]))
    cv2.imwrite(new_img_name, prednormr.astype('uint8'))   
    
    coords = (1/s) * np.stack(np.where(pred[0]))[[1, 0]].transpose()
    print(len(coords))
    
    time_taken = time.time() - start_time - time_taken
    print('Prediction time: %.2f' % time_taken)


    filename = os.path.basename(img_name)
    file_size = os.path.getsize(img_name)
    file_attributes = "{'Altura':'10'}"
    region_count = coords.size

    for idx in range(len(coords)):
        cx, cy = np.int0(coords[idx])
        r = {'filename': filename,
             'file_size': file_size,
             'file_attributes': file_attributes,
             'region_count': region_count,
             'region_id' : idx,
             'region_shape_attributes': "{'name':'point','cx':" + str(cx) + ",'cy':" + str(cy) + "}",
             'region_attributes': "{'Planta':'Soja'}"
            }
        regions.append(r)
# Out:
# DJI_0187.JPG
# PreProc time: 1.39
# 11 8
# 626
# Prediction time: 7.61
# DJI_0188.JPG
# PreProc time: 1.40
# 11 8
# 1017
# Prediction time: 7.49
# DJI_0189.JPG
# PreProc time: 1.40
# 11 8
# 1361
# Prediction time: 7.58
# DJI_0190.JPG
# PreProc time: 1.40
# 11 8
# 971
# Prediction time: 7.49
# DJI_0191.JPG
# PreProc time: 1.40
# 11 8
# 973
# Prediction time: 7.53
# DJI_0192.JPG
# PreProc time: 1.40
# 11 8
# 1097
# Prediction time: 7.51
# DJI_0193.JPG
# PreProc time: 1.40
# 11 8
# 1894
# Prediction time: 7.52
# DJI_0194.JPG
# PreProc time: 1.38
# 11 8
# 872
# Prediction time: 7.54
# DJI_0195.JPG
# PreProc time: 1.37
# 11 8
# 1069
# Prediction time: 7.54
# DJI_0197.JPG
# PreProc time: 1.38
# 11 8
# 1406
# Prediction time: 7.55
# DJI_0198.JPG
# 11 8
# 3566
# Prediction time: 7.67
# DJI_0280.JPG
# PreProc time: 1.36
# 11 8
# 3719
# Prediction time: 7.58
# DJI_0281.JPG
# PreProc time: 1.31
# 11 8
# 2137
# Prediction time: 7.57
# DJI_0289.JPG
# PreProc time: 1.38
# 11 8
# 3576
# Prediction time: 7.59
# DJI_0290.JPG
# PreProc time: 1.37
# 11 8
# 4012
# Prediction time: 7.59
# DJI_0291.JPG
# PreProc time: 1.27
# 11 8
# 2192
# Prediction time: 7.65
# DJI_0292.JPG
# PreProc time: 1.27
# 11 8
# 1575
# Prediction time: 7.54
# DJI_0293.JPG
# PreProc time: 1.26
# 11 8
# 2159
# Prediction time: 7.53
# DJI_0294.JPG
# PreProc time: 1.29
# 11 8
# 1696
# Prediction time: 7.55
# DJI_0295.JPG
# PreProc time: 1.29
# 11 8
# 1554
# Prediction time: 7.49
# DJI_0296.JPG
# PreProc time: 1.26
# 11 8
# 1208
# Prediction time: 7.57
# DJI_0297.JPG
# PreProc time: 1.27
# 11 8
# 1694
# Prediction time: 7.67
# DJI_0298.JPG
# PreProc time: 1.38
# 11 8
# 4595
# Prediction time: 7.58
# DJI_0299.JPG
# PreProc time: 1.36
# 11 8
# 2905
# Prediction time: 7.54
# DJI_0300.JPG
# PreProc time: 1.35
# 11 8
# 3493
# Prediction time: 7.50
# DJI_0341.JPG
# PreProc time: 1.34
# 11 8
# 2011
# Prediction time: 7.57
# DJI_0354.JPG
# DJI_0355.JPG
# DJI_0364.JPG
# DJI_0365.JPG
# DJI_0366.JPG
# PreProc time: 1.31
# 11 8
# 1667
# Prediction time: 7.61
# DJI_0367.JPG
# DJI_0368.JPG
# DJI_0371.JPG
# DJI_0372.JPG
# DJI_0373.JPG
# DJI_0378.JPG
# PreProc time: 1.31
# 11 8
# 908
# Prediction time: 7.56
# DJI_0379.JPG
# PreProc time: 1.31
# 11 8
# 1192
# Prediction time: 7.53
# DJI_0381.JPG
# PreProc time: 1.34
# 11 8
# 2553
# Prediction time: 7.58
# DJI_0385.JPG
# PreProc time: 1.30
# 11 8
# 686
# Prediction time: 7.60
# DJI_0386.JPG
# PreProc time: 1.34
# 11 8
# 3018
# Prediction time: 7.58

# %%
plt.imshow(cat.cpu().data.numpy())

# %%
ptsdf = pd.DataFrame.from_dict(regions)
ptsdf.file_attributes = ptsdf.file_attributes.str.replace("'", '"')
ptsdf.region_shape_attributes = ptsdf.region_shape_attributes.str.replace("'", '"')
ptsdf.region_attributes = ptsdf.region_attributes.str.replace("'", '"')
ptsdf.to_csv('../data/SP_pred_VIA.csv', index = False)

# %%
plt.imshow(prednormr)

# %%
plt.imshow(imgo[:,:,[2,1,0]])
